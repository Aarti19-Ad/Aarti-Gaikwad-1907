# %% [markdown]
# List

# %%
l = [23,45,67,89,12]

# %%
print(l)
# Out:
# [23, 45, 67, 89, 12]

# %%
#List are hetrogeneous and duplicates are allowed

# %%
l1 = [23,45,67.90,89,12,"Python","Java",23,45]

# %%
l1
# Out:
# [23, 45, 67.9, 89, 12, 'Python', 'Java', 23, 45]

# %%
#Lists are ordered

# %%
l1
# Out:
# [23, 45, 67.9, 89, 12, 'Python', 'Java', 23, 45]

# %%
l1[2]
# Out:
# 67.9

# %%
l1[-3]
# Out:
# 'Java'

# %%
#Lists are mutable

# %%
l1[1] = 100

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'Python', 'Java', 23, 45]

# %%
l1[-3] = True

# %%
l1
# Out:
# [23, 100, 67.9, 89, 12, 'Python', True, 23, 45]

# %%
l = [21,23,45,67,89,11]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[1:4]
# Out:
# [23, 45, 67]

# %%
l[1:-2]
# Out:
# [23, 45, 67]

# %%
#21,45,89

# %%
l[0:6:2]
# Out:
# [21, 45, 89]

# %%
l[::2]
# Out:
# [21, 45, 89]

# %%
#Reverse the list

# %%
l[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l[1:4] = [100,200,300]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l1 = [12,34,56,23]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 34, 23]

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
#Membership operator

# %%
l = [21, 100, 200, 300, 89, 11]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
89 in l
# Out:
# True

# %%
1907 in l
# Out:
# False

# %%
#Arithmetic operators

# %%
l = [21, 100, 200, 300, 89, 11]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
'OK' * 3 #String repetition
# Out:
# 'OKOKOK'

# %%
l * 2 #Repitition of list
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
l + [60,70,80] #Concatenation of list
# Out:
# [21, 100, 200, 300, 89, 11, 60, 70, 80]

# %%
#Take 2 different list and add

# %%
l2 = [19,7,9,1,11]
l3 = [29,15,14,30]

# %%
l4 = l2 +l3

# %%
l4
# Out:
# [19, 7, 9, 1, 11, 29, 15, 14, 30]

# %%
#Iteration over list

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
#Iterate over list and print square of each element

# %%
for i in l:
    print(i ** 2, end = ' ')
# Out:
# 441 10000 40000 90000 7921 121

# %%
#Print odd number on the list

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
for i in l:
    if i % 2 == 1:
        print(i, end = ' ')
# Out:
# 21 89 11

# %%
#List comprehension -> [expression for_loop, if_condition]

# %%
newl = [i ** 2 for i in l]

# %%
newl
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
newl2 = [i for i in l if i % 2 == 1]

# %%
newl2
# Out:
# [21, 89, 11]

# %%
names = ['Aryan', 'atharv', 'samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
names
# Out:
# ['Aryan', 'atharv', 'samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
#Create a new list with names which start with s or 'S'

# %%
newl3 = [i for i in names if i.startswith('s') or i.startswith('S')]

# %%
newl3
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
#And this way

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# samruddhi
# swaraj
# Sukanya
# shivraj

# %%
newl4 = [i for i in names if i.lower().startswith('s')]

# %%
newl4
# Out:
# ['samruddhi', 'swaraj', 'Sukanya', 'shivraj']

# %%
len(l)
# Out:
# 6

# %%
max(l)
# Out:
# 300

# %%
min(l)
# Out:
# 11

# %%
sorted(l)
# Out:
# [11, 21, 89, 100, 200, 300]

# %%
sorted(l,reverse = True)
# Out:
# [300, 200, 100, 89, 21, 11]

# %%
#List methods

# %%
#Append

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.append(1000)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1 = [1,2,3]
l2 = [1,2,3]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1] = 1907

# %%
l1
# Out:
# [1, 2, 3, [100, 1907]]

# %%
#Insert

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l.insert(1,78)

# %%
l
# Out:
# [21, 78, 100, 200, 300, 89, 11, 1000]

# %%
l.remove(78)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
#Pop

# %%
l.pop()
# Out:
# 1000

# %%
l.pop(3)
# Out:
# 300

# %%
l.index(89)
# Out:
# 3

# %%
l.sort(reverse = True)

# %%
l
# Out:
# [200, 100, 89, 21, 11]
