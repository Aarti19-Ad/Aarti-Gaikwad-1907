# %%
# Pandas

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 1D data structures in pandas

# %%
# Panda series

# %%
import pandas as pd

# %%
s = pd.Series([10, 20, 30])

# %%
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s1 = pd.Series([19, 7, 8, 11, 6])

# %%
s1
# Out:
# 0    19
# 1     7
# 2     8
# 3    11
# 4     6
# dtype: int64

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s2 = pd.Series(['Aarti',17,85], index=['Name', 'Age', 'Marks'])

# %%
s2
# Out:
# Name     Aarti
# Age         17
# Marks       85
# dtype: object

# %%
# From dictionary

# %%
data = {'Name':"Aarti", 'Age':17, 'Marks': 90}

# %%
s = pd.Series(data)

# %%
s
# Out:
# Name     Aarti
# Age         17
# Marks       90
# dtype: object

# %%
data1 = {'Name':"Aarti", 'Age':17, 'Marks': 90, 'Year': "2nd Year"}

# %%
s = pd.Series(data1)

# %%
s
# Out:
# Name        Aarti
# Age            17
# Marks          90
# Year     2nd Year
# dtype: object

# %%
# From a single value

# %%
s = pd.Series(5, index=[0,1,2,3])

# %%
s
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
s = pd.Series(19, index=[0,1,2,3,4,5,6,7])

# %%
s
# Out:
# 0    19
# 1    19
# 2    19
# 3    19
# 4    19
# 5    19
# 6    19
# 7    19
# dtype: int64

# %%
# Attributes

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s.values
# Out:
# array([10, 20, 30])

# %%
s.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (3,)

# %%
# Data manipulation

# %%
s = pd.Series([1, 2, 3])

# %%
print(s * 3)
# Out:
# 0    3
# 1    6
# 2    9
# dtype: int64

# %%
# Handling missing values

# %%
s = pd.Series([1, None, 3])

# %%
s
# Out:
# 0    1.0
# 1    NaN
# 2    3.0
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
s.dropna()
# Out:
# 0    1.0
# 2    3.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    0.0
# 2    3.0
# dtype: float64

# %%
# Indexing

# %%
s = pd.Series([10, 20, 30], index=['a', 'b', 'c'])

# %%
s
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s['a']
# Out:
# np.int64(10)

# %%
s['c']
# Out:
# np.int64(30)
