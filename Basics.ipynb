# %%
print("Hello")
# Out:
# Hello

# %%
#Add above -> A, below -> del ->

# %%
Num1 = 19

# %%
Name = "Aarti"

# %%
print(Name)
# Out:
# Aarti

# %%
rate_of_interest = 5

# %%
rate_of_interest
# Out:
# 5

# %%
Pass = 1907

# %%
Pass
# Out:
# 1907

# %%
num = 19
num2 = 80.00
name = "Aarti"

# %%
type(num)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
num = 21891286424 ** 234

# %%
num
# Out:
# ...

# %%
#Float

# %%
num = 23e4

# %%
type(num)
# Out:
# float

# %%
num
# Out:
# 230000.0

# %%
#String

# %%
sent = "I like Python programming"

# %%
print(sent)
# Out:
# I like Python programming

# %%
#I like Python programming
#I like python programming

# %%
sent = 'I like "python" programming'
print(sent)
# Out:
# I like "python" programming

# %%
sent = "I like 'python' programming"
print(sent)
# Out:
# I like 'python' programming

# %%
#Simple addition programm

# %%
num1 = 19
num2 = 7
sum = num1 + num2
print(sum)
# Out:
# 26

# %%
num1 = 19; num2 = 7; sum = num1 + num2; print(sum);
# Out:
# 26
